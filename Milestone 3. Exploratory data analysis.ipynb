# %% [markdown]
# # **TikTok Project**

# %% [markdown]
# # **Exploratory data analysis**
#
#
# **The purpose** of this notebook is to conduct exploratory data analysis on a provided data set and continue the investigation.
#
# **The goal** is to explore the dataset and create visualizations.

# %% [markdown]
# # **PACE stages**

# %% [markdown]
# ## **PACE: Plan**

# %%
# Import packages for data manipulation
import pandas as pd
import numpy as np

# Import packages for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset into dataframe
data = pd.read_csv("tiktok_dataset.csv")

# %% [markdown]
# ## **PACE: Analyze**

# %% [markdown]
# ### **Data exploration and cleaning**

# %%
# Display and examine the first few rows of the dataframe
data.head()
# Out:
#    # claim_status    video_id  video_duration_sec  \
# 0  1        claim  7017666017                  59
# 1  2        claim  4014381136                  32
# 2  3        claim  9859838091                  31
# 3  4        claim  1866847991                  25
# 4  5        claim  7105231098                  19
#
#                             video_transcription_text verified_status  \
# 0  someone shared with me that drone deliveries a...    not verified
# 1  someone shared with me that there are more mic...    not verified
# 2  someone shared with me that american industria...    not verified
# 3  someone shared with me that the metro of st. p...    not verified
# 4  someone shared with me that the number of busi...    not verified
#
#   author_ban_status  video_view_count  video_like_count  video_share_count  \
# 0      under review          343296.0           19425.0              241.0
# 1            active          140877.0           77355.0            19034.0
# ...

# %%
# Get the size of the data
data.size
# Out:
# 232584

# %%
# Get the shape of the data
print(f"The dataset has {data.shape[1]} columns and {data.shape[0]} rows.")
# Out:
# The dataset has 12 columns and 19382 rows.

# %%
# Get basic information about the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19382 entries, 0 to 19381
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   #                         19382 non-null  int64
#  1   claim_status              19084 non-null  object
#  2   video_id                  19382 non-null  int64
#  3   video_duration_sec        19382 non-null  int64
#  4   video_transcription_text  19084 non-null  object
#  5   verified_status           19382 non-null  object
#  6   author_ban_status         19382 non-null  object
#  7   video_view_count          19084 non-null  float64
#  8   video_like_count          19084 non-null  float64
#  9   video_share_count         19084 non-null  float64
#  10  video_download_count      19084 non-null  float64
#  11  video_comment_count       19084 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 1.8+ MB

# %%
# Generate a table of descriptive statistics
data.describe()
# Out:
#                   #      video_id  video_duration_sec  video_view_count  \
# count  19382.000000  1.938200e+04        19382.000000      19084.000000
# mean    9691.500000  5.627454e+09           32.421732     254708.558688
# std     5595.245794  2.536440e+09           16.229967     322893.280814
# min        1.000000  1.234959e+09            5.000000         20.000000
# 25%     4846.250000  3.430417e+09           18.000000       4942.500000
# 50%     9691.500000  5.618664e+09           32.000000       9954.500000
# 75%    14536.750000  7.843960e+09           47.000000     504327.000000
# max    19382.000000  9.999873e+09           60.000000     999817.000000
#
#        video_like_count  video_share_count  video_download_count  \
# count      19084.000000       19084.000000          19084.000000
# mean       84304.636030       16735.248323           1049.429627
# std       133420.546814       32036.174350           2004.299894
# ...

# %% [markdown]
# ## **PACE: Construct**

# %% [markdown]
# ### **Build visualizations**

# %% [markdown]
# #### **video_duration_sec**

# %%
# Create a boxplot to visualize distribution of `video_duration_sec`
sns.set_theme(style="darkgrid")
plt.figure(figsize=(7, 3))
sns.boxplot(x=data["video_duration_sec"], color='b')
plt.title("Boxplot of Video Durations", fontsize=14)
plt.xlabel("Video Duration (Seconds)")
plt.show()

# %%
# Create a histogram of the values in the `video_duration_sec` column to further explore the distribution of this variable.
plt.figure(figsize=(6, 3))
sns.histplot(data=data, x="video_duration_sec", color='b')

plt.title("Distribution of Video Durations", fontsize=14)
plt.xlabel("Video Duration (Seconds)")
plt.show()

# %% [markdown]
# The boxplot shows that most videos have durations between 20 and 45 seconds, with a median around 30-35 seconds. The histogram reveals a fairly even distribution but with peaks at 10, 20, 40, and 60 seconds, suggesting common standard durations.

# %% [markdown]
# #### **video_view_count**

# %%
# Create a boxplot to visualize distribution of `video_view_count`
plt.figure(figsize=(7, 3))
sns.boxplot(x=data["video_view_count"], color='b')
plt.title("Boxplot of Video View Count Values", fontsize=14)
plt.xlabel("Video View Count")
plt.show()

# %%
# Create a histogram of the values in the `video_view_count` column to further explore the distribution of this variable.
plt.figure(figsize=(6, 3))
sns.histplot(data=data, x="video_view_count", color='b')
plt.title("Distribution of Video View Count Values", fontsize=14)
plt.xlabel("Video View Count")
plt.show()

# %% [markdown]
# The video view count distribution is highly right-skewed, with most values concentrated near zero and a long tail extending to higher counts. The boxplot shows potential outliers, indicating some videos have significantly more views than the majority. The long right whisker confirms extreme values. A log transformation could help normalize the data for analysis.

# %% [markdown]
# #### **video_like_count**

# %%
# Create a boxplot to visualize distribution of `video_like_count`
plt.figure(figsize=(7, 3))
sns.boxplot(x=data["video_like_count"], color='b')
plt.title("Boxplot of Video Like Count Values", fontsize=14)
plt.xlabel("Video Like Count")
plt.show()

# %%
# Create a histogram of the values in the `video_like_count` column to further explore the distribution of this variable.
plt.figure(figsize=(6, 3))
sns.histplot(data=data, x="video_like_count", color='b')

plt.title("Distribution of Video Like Count Values", fontsize=14)
plt.xlabel("Video Like Count")
plt.show()

# %% [markdown]
# The video like count distribution is highly right-skewed as well, with many low values and a long tail of higher values. The boxplot shows a large number of outliers, indicating that some videos receive significantly more likes than others. The long right whisker confirms extreme values, suggesting the data may benefit from transformation for analysis.

# %% [markdown]
# #### **video_comment_count**

# %%
# Create a boxplot to visualize distribution of `video_comment_count`
plt.figure(figsize=(7, 3))
sns.boxplot(x=data["video_comment_count"], color='b')
plt.title("Boxplot of Video Comment Count Values", fontsize=14)
plt.xlabel("Video Comment Count")
plt.show()

# %%
# Create a histogram of the values in the `video_comment_count` column to further explore the distribution of this variable.
plt.figure(figsize=(6, 3))
sns.histplot(data=data, x="video_comment_count", color='b')

plt.title("Distribution of Video Comment Count Values", fontsize=14)
plt.xlabel("Video Comment Count")
plt.show()

# %% [markdown]
# The distribution of "Video Comment Count" is heavily right-skewed, with most videos receiving very few comments. A long tail in the histogram indicates a small number of videos with exceptionally high comment counts, pulling the distribution's mean towards higher values. This suggests a significant disparity in comment engagement across videos, with a few outliers driving the average up.

# %% [markdown]
# #### **video_share_count**

# %%
# Create a boxplot to visualize distribution of `video_share_count`
plt.figure(figsize=(7, 3))
sns.boxplot(x=data["video_share_count"], color='b')
plt.title("Boxplot of Video Share Count Values", fontsize=14)
plt.xlabel("Video Share Count")
plt.show()

# %% [markdown]
# *Create* a histogram of the values in the `video_share_count` column to further explore the distribution of this variable.

# %%
# Create a histogram
plt.figure(figsize=(6, 3))
sns.histplot(data=data, x="video_share_count", color='b')

plt.title("Distribution of Video Share Count Values", fontsize=14)
plt.xlabel("Video Share Count")
plt.show()

# %% [markdown]
# The "Video Share Count" distribution is strongly right-skewed.  Most videos have few shares, while a small number have extremely high counts. This is evident in both the histogram's long tail and the boxplot's outliers.

# %% [markdown]
# #### **video_download_count**

# %%
# Create a boxplot to visualize distribution of `video_download_count`
plt.figure(figsize=(7, 3))
sns.boxplot(x=data["video_download_count"], color='b')
plt.title("Boxplot of Video Download Count Values", fontsize=14)
plt.xlabel("Video Download Count")
plt.show()

# %% [markdown]
# Create a histogram of the values in the `video_download_count` column to further explore the distribution of this variable.

# %%
# Create a histogram
plt.figure(figsize=(6, 3))
sns.histplot(data=data, x="video_download_count", color='b')

plt.title("Distribution of Video Download Count Values", fontsize=14)
plt.xlabel("Video Download Count")
plt.show()

# %% [markdown]
# Both the boxplot and the histogram for "Video Download Count Values" depict a highly right-skewed distribution. The majority of videos have low download counts, clustering near zero in the histogram and reflected by the narrow box in the boxplot. A long tail in the histogram and outliers in the boxplot indicate a few videos with significantly higher download counts, pulling the mean towards higher values. This pattern suggests that while most videos receive few downloads, a select few achieve a much larger number of downloads.

# %% [markdown]
# #### **Claim status by verification status**
#
# Now, let's create a histogram with four bars: one for each combination of claim status and verification status.

# %%
# Create a histogram
plt.figure(figsize=(6, 3))
sns.countplot(x='verified_status', hue='claim_status', data=data, palette='crest')
plt.title("Distribution of Claim Status across Verification Status", fontsize=14)
plt.xlabel("Verification Status")
plt.show()

# %% [markdown]
# There are significantly fewer verified users compared to unverified users. Verified users are also more likely to post opinions than claims, while unverified users show a higher tendency to post claims. This suggests that verification status may correlate with the type of content users choose to post.

# %% [markdown]
# #### **Claim status by author ban status**
#
# In the initial EDA we used a `groupby()` statement to examine the count of each claim status for each author ban status. Now, let's use a histogram to communicate the same information.

# %%
# Create a histogram
plt.figure(figsize=(6, 3))
sns.countplot(x='author_ban_status', hue='claim_status', data=data, palette='crest')
plt.title("Distribution of Claim Status Across Author Ban Categories", fontsize=14)
plt.xlabel("Author Ban Category")
plt.show()

# %% [markdown]
# The number of active authors is significantly higher than banned authors for both claims and opinions. Active authors post substantially more claims and opinions compared to banned authors.  There's also a noticeable trend where active authors have a higher proportion of opinions compared to claims, while banned authors have a greater tendency towards claims. This suggests that author status (active vs. banned) strongly influences the volume and type of content posted.

# %% [markdown]
# #### **Median view counts by ban status**
#
# Let's create a bar plot with three bars: one for each author ban status. The height of each bar should correspond with the median number of views for all videos with that author ban status.

# %%
# Calculate median views for each author ban status
median_views = data.groupby('author_ban_status')['video_view_count'].median().reset_index()

# Create bar plot
plt.figure(figsize=(6, 3))
sns.barplot(data=median_views, x='author_ban_status', y='video_view_count', palette='crest', hue='video_view_count')

# Set labels and title
plt.xlabel('Author Ban Status')
plt.ylabel('Median Video Views')
plt.title('Median Video Views by Author Ban Status', fontsize=14)
plt.show()

# %% [markdown]
# The median view counts for banned and under review authors are significantly higher than those of active authors.  This suggests that high view counts might be a good indicator of non-active (banned or under review) claim status.  Therefore, video views could potentially be a strong predictor for identifying claims associated with authors who are not actively participating.

# %%
# Calculate the median view count for claim status.
median_views = data.groupby('claim_status')['video_view_count'].median().reset_index()

# Create bar plot
plt.figure(figsize=(6, 3))
sns.barplot(data=median_views, x='claim_status', y='video_view_count', palette='crest', hue='video_view_count')

# Set labels and title
plt.xlabel('Claim Status')
plt.ylabel('Median Video Views')
plt.title('Median Video Views by Claim Status', fontsize=14)
plt.show()

# %% [markdown]
# #### **Total views by claim status**
#
# Let's create a pie graph that depicts the proportions of total views for claim videos and total views for opinion videos.

# %%
# Create a pie graph
total_views = data.groupby('claim_status')['video_view_count'].sum()
palette_color = sns.color_palette('Paired') 
plt.figure(figsize=(8, 3))
plt.pie(total_views, labels=total_views.index, autopct='%1.1f%%', colors=palette_color)
plt.title('Proportion of Total Views for Claim vs. Opinion Videos', fontsize=14)
plt.show()

# %% [markdown]
# Claim videos account for an overwhelming 99% of total views, indicating they are significantly more popular than opinion videos. Opinion videos, conversely, represent only 1% of the total views, highlighting a stark difference in audience engagement. This suggests that claim-based content is far more likely to attract viewership compared to opinion-based content.

# %% [markdown]
# ### **Determine outliers**
#
# When building predictive models, the presence of outliers can be problematic. For example, if we were trying to predict the view count of a particular video, videos with extremely high view counts might introduce bias to a model. Also, some outliers might indicate problems with how data was captured or recorded.
#
# The ultimate objective of the TikTok project is to build a model that predicts whether a video is a claim or opinion. The analysis we've performed indicates that a video's engagement level is strongly correlated with its claim status. There's no reason to believe that any of the values in the TikTok data are erroneously captured, and they align with expectation of how social media works: a very small proportion of videos get super high engagement levels. That's the nature of viral content.
#
# Nonetheless, it's good practice to get a sense of just how many of your data points could be considered outliers. The definition of an outlier can change based on the details of your project, and it helps to have domain expertise to decide a threshold. You've learned that a common way to determine outliers in a normal distribution is to calculate the interquartile range (IQR) and set a threshold that is 1.5 * IQR above the 3rd quartile.
#
# In this dataset, the values for the count variables are not normally distributed. They are heavily skewed to the right. One way of modifying the outlier threshold is by calculating the **median** value for each variable and then adding 1.5 * IQR.

# %%
columns = ['video_view_count', 'video_like_count', 'video_share_count', 
           'video_download_count', 'video_comment_count']

for col in columns:
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)

    IQR = Q3 - Q1

    median = data[col].median()
    threshold = median + IQR * 1.5

    print(f"Number of outliers, {col}: {(data[col] > threshold).sum()}")
# Out:
# Number of outliers, video_view_count: 2343
# Number of outliers, video_like_count: 3468
# Number of outliers, video_share_count: 3732
# Number of outliers, video_download_count: 3733
# Number of outliers, video_comment_count: 3882

# %%
# Create a scatterplot of `video_view_count` versus `video_like_count` according to 'claim_status'
plt.figure(figsize=(6, 3))
sns.scatterplot(data=data, x='video_view_count', y='video_like_count', 
                hue='claim_status', palette="Paired")
plt.xlabel('Video View Count')
plt.ylabel('Video Like Count')
plt.title('Scatterplot of Video Views vs. Likes by Claim Status', fontsize=14)
plt.show()

# %%
sns.color_palette("Paired")[1]
# Out:
# (0.12156862745098039, 0.47058823529411764, 0.7058823529411765)

# %%
# Create a scatterplot of ``video_view_count` versus `video_like_count` for opinions only
opinion_data = data[data['claim_status'] == 'opinion']
plt.figure(figsize=(6, 3))

# Create a custom palette starting from the second color
custom_palette = [sns.color_palette("Paired")[1]]
sns.scatterplot(data=opinion_data, x='video_view_count', y='video_like_count', 
                hue='claim_status', palette=custom_palette)

plt.xlabel('Video View Count')
plt.ylabel('Video Like Count')
plt.title('Scatterplot of Video Views vs. Likes by Claim Status', fontsize=14)
plt.show()

# %% [markdown]
# ## **PACE: Execute**

# %% [markdown]
# ### **Results and evaluation**

# %% [markdown]
# What I Have Learned About the Dataset:
#
# 1. Video duration peaks at 10, 20, 40, and 60 seconds.
#
# 2. Engagement metrics (views, likes, shares, downloads, comments) are highly right-skewed with many outliers.
#
# 3. Claim videos dominate, accounting for 99% of total views.
#
# 4. Verified users post more opinions, while unverified users post more claims.
#
# 5. Banned users have higher median view counts, suggesting controversial content gets more engagement.
#
# My Other Questions:
#
# 1. How does engagement (likes, shares, comments) differ between claims and opinions?
#
# 2. Are there patterns in the content (keywords, sentiment) of highly engaging claim videos?
#
# 3. How should missing claim_status values be handled to ensure accurate classification?
#
# 4. What linguistic differences exist between claims and opinions?
#
# 5. Should TikTok adjust moderation policies based on banned users getting high views?
#
# My Client Would Likely Want to Know
#
# 1. Why do claim videos attract significantly more views than opinions?
#
# 2. Do specific keywords, topics, or video durations contribute to viral success?
#
# 3. Can we automate claim detection using machine learning?
#
# 4. How can we reduce the spread of misinformation while maintaining user engagement?
#
# 5. Should TikTok alter its policies for banned users who generate high engagement?
